# %%
import cv2

cv2.namedWindow("window test")
cv2.waitKey()
cv2.destroyAllWindows()

# %%
src = cv2.imread("IU.jpg")

cv2.imshow("src", src)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
import cv2

capture = cv2.VideoCapture(0)
# capture.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
# capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)

while cv2.waitKey(10) < 0:
    ret, frame = capture.read()
    cv2.imshow("VideoFrame", frame)

capture.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 7
#       3 capture = cv2.VideoCapture(0)
#       4 # capture.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
#       5 # capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
# ----> 7 while cv2.waitKey(10) < 0:
#       8     ret, frame = capture.read()
#       9     cv2.imshow("VideoFrame", frame)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import cv2

# %%
capture = cv2.VideoCapture("sample_1280x720_surfing_with_audio.avi")
fps=capture.get(cv2.CAP_PROP_FPS)
total_frame=capture.get(cv2.CAP_PROP_FRAME_COUNT)
while cv2.waitKey(int(1000.0/fps)) < 0:
    if capture.get(cv2.CAP_PROP_POS_FRAMES)==total_frame-1:
        capture.get(cv2.CAP_PROP_POS_FRAMES,0)
    ret, frame = capture.read()
    cv2.imshow("VideoFrame", frame)
    print(ret)
capture.release()
cv2.destroyAllWindows()
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
import cv2

src = cv2.imread("IU.jpg")

height, width, channel = src.shape
matrix = cv2.getRotationMatrix2D((width/2, height/2), 90, 0.5)
# matrix = cv2.getRotationMatrix2D((0, 0), 45, 1)
# matrix = cv2.getRotationMatrix2D((width, height), 45, 1)
dst = cv2.warpAffine(src, matrix, (width, height))

cv2.imshow("src", src)
cv2.imshow("dst", dst)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
import cv2

src = cv2.imread("IU.jpg", cv2.IMREAD_COLOR)

dst = src.copy() 
roi = src[100:400, 200:500]
dst[0:300, 0:300] = roi

cv2.imshow("src", src)
cv2.imshow("dst", dst)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
import cv2

src = cv2.imread("IU.jpg", cv2.IMREAD_COLOR)

dst = cv2.resize(src, dsize=(640, 480), interpolation=cv2.INTER_AREA)
dst2 = cv2.resize(src, dsize=(0, 0), fx=0.4, fy=0.7, interpolation=cv2.INTER_LINEAR)

cv2.imshow("src", src)
cv2.imshow("dst", dst)
cv2.imshow("dst2", dst2)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

src = cv2.imread("IU.jpg", cv2.IMREAD_COLOR)
b, g, r = cv2.split(src)
inverse = cv2.merge((r, g, b))
normal = cv2.merge((b, g, r))

height, width, channel = src.shape
zero = np.zeros((height, width, 1), dtype=np.uint8)
bgz = cv2.merge((b, g, zero))

cv2.imshow("b", b)
cv2.imshow("g", g)
cv2.imshow("r", r)
cv2.imshow("inverse", inverse)
cv2.imshow("normal", normal)
cv2.imshow("bgz", bgz)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
import cv2

src = cv2.imread("IU.jpg", cv2.IMREAD_COLOR)

gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)
rst, dst = cv2.threshold(gray, 130,255,cv2.THRESH_BINARY)
#print(gray.shape)
print(dst.shape)

cv2.imshow("gray", gray)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
import cv2

src = cv2.imread("IU.jpg", cv2.IMREAD_COLOR)
gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)

sobel = cv2.Sobel(gray, cv2.CV_8U, 1, 0, 3)
laplacian = cv2.Laplacian(gray, cv2.CV_8U, ksize=3)
canny = cv2.Canny(src, 10, 255)

cv2.imshow("sobel", sobel)
cv2.imshow("laplacian", laplacian)
cv2.imshow("canny", canny)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
import cv2

capture = cv2.VideoCapture(0)

while True:
    ret, frame = capture.read()
    if not ret:
        break
    
    canny = cv2.Canny(frame, 100, 200)
    
    cv2.imshow("VideoFrame", canny)
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

capture.release()
cv2.destroyAllWindows()

# %%
#실습 1-1

import cv2

# 웹캠을 켭니다.
cap = cv2.VideoCapture(0)

while True:
    # 웹캠으로부터 영상을 받아옵니다.
    ret, frame = cap.read()

    if not ret:
        break

    blur = cv2.blur(frame, (10, 10))

    # 결과 영상을 화면에 출력합니다.
    cv2.imshow('blur', blur)

    # 'q'를 누르면 종료합니다.
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# 웹캠을 끕니다.
cap.release()
cv2.destroyAllWindows()

# %%
#실습 1-2

import cv2

# 웹캠을 켭니다.
cap = cv2.VideoCapture(0)

while True:
    # 웹캠으로부터 영상을 받아옵니다.
    ret, frame = cap.read()

    if not ret:
        break

    canny = cv2.Canny(frame, 100, 200)

    # 결과 영상을 화면에 출력합니다.
    cv2.imshow('canny', canny)

    # 'q'를 누르면 종료합니다.
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# 웹캠을 끕니다.
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

x_offset = 200
y_offset = 200

# Load two images
img_bg = cv2.imread('IU.jpg')
img_fg = cv2.imread('IU2.jpg', cv2.IMREAD_UNCHANGED)

# cv2.imshow('img1',img_bg)
# cv2.imshow('img2',img_fg)

_, mask = cv2.threshold(img_fg[:,:,3], 1, 255, cv2.THRESH_BINARY)
mask_inv = cv2.bitwise_not(mask)

cv2.imshow('mask',mask)
cv2.imshow('mask_inv',mask_inv)

rows,cols,channels = img_fg.shape
roi = img_bg[x_offset:x_offset+rows, y_offset:y_offset+cols ]

masked_fg = cv2.bitwise_and(img_fg, img_fg, mask=mask)
masked_bg = cv2.bitwise_and(roi, roi, mask=mask_inv)

cv2.imshow('masked_fg',masked_fg)
cv2.imshow('masked_bg',masked_bg)

print("masked_bg", masked_bg.shape)
print("masked_fg", masked_fg.shape)
dst = cv2.add(masked_fg[:,:,:3],masked_bg)
# print("dst", dst)
# added = masked_fg + masked_bg
img_bg[x_offset:x_offset+rows, y_offset:y_offset+cols ] = dst
cv2.imshow('dst',dst)
cv2.imshow('img_bg',img_bg)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[30], line 14
#       9 img_fg = cv2.imread('IU2.jpg', cv2.IMREAD_UNCHANGED)
#      11 # cv2.imshow('img1',img_bg)
#      12 # cv2.imshow('img2',img_fg)
# ---> 14 _, mask = cv2.threshold(img_fg[:,:,3], 1, 255, cv2.THRESH_BINARY)
#      15 mask_inv = cv2.bitwise_not(mask)
#      17 cv2.imshow('mask',mask)
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed

# %%
#실습 1-1

import cv2

# 웹캠을 켭니다.
cap = cv2.VideoCapture(0)
img_bg = cv2.imread('IU.jpg')

while True:
    # 웹캠으로부터 영상을 받아옵니다.
    ret, frame = cap.read()
    
    # img_bg를 웹캠 영상에 맞게 resize
    img_bg = cv2.resize(img_bg, (frame.shape[1], frame.shape[0]))

    # 웹캠 영상과 배경 이미지를 합칩니다.
    result = cv2.addWeighted(frame, 0.8, img_bg, 0.2, 0)

    cv2.imshow("VideoFrame", result)
    # 'q'를 누르면 종료합니다.
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# 웹캠을 끕니다.
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

src = np.zeros((768, 1366, 3), dtype=np.uint8)

src = cv2.line(src, (100, 100), (1200, 100), (0, 0, 255), 3, cv2.LINE_AA)
src = cv2.line(src, (100, 150), (1200, 150), (0, 255, 255), 3, cv2.LINE_4)

src = cv2.circle(src, (300, 300), 50, (0, 255, 0), cv2.FILLED, cv2.LINE_4)
src = cv2.rectangle(src, (500, 200), (1000, 400), (255, 0, 0), 5, cv2.LINE_8)
src = cv2.ellipse(src, (1200, 300), (100, 50), 0, 90, 180, (255, 255, 0), 2)

pts1 = np.array([[100, 500], [300, 500], [200, 600]])
pts2 = np.array([[600, 500], [800, 500], [700, 600]])
src = cv2.polylines(src, [pts1], True, (0, 255, 255), 2)
src = cv2.fillPoly(src, [pts2], (255, 0, 255), cv2.LINE_AA)

src = cv2.putText(src, "Hi,OpenCV", (900, 600), cv2.FONT_HERSHEY_COMPLEX, 2, (255, 255, 255), 3)

cv2.imshow("src", src)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

img = np.zeros(shape = (512, 512, 3), dtype = np.uint8) + 255

x1, x2 = 100, 400
y1, y2 = 100, 400
cv2.rectangle(img, (x1, y1), (x2, y2), (0, 0, 255))

pt1 = 120, 50
pt2 = 300, 500
cv2.line(img, pt1, pt2, (255, 0, 0), 2)

imgRect = (x1, y1, x2-x1, y2-y1)
retval, rpt1, rpt2 = cv2.clipLine(imgRect, pt1, pt2)
if retval:
    cv2.circle(img, rpt1, radius=5, color = (0, 255, 0),thickness=-1)
    cv2.circle(img, rpt2, radius=5, color=(0, 255, 0), thickness=-1)

cv2.imshow('img',img)
cv2.waitKey()
cv2.destroyAllWindows()
