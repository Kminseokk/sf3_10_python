# %%
# https://www.kaggle.com/datasets/andrewmvd/animal-faces/data

# https://teachablemachine.withgoogle.com/
# 시작하기 > 이미지 프로젝트 > 표준 이미지 모델 > 클래스 별 이미지 샘플 업로드 > 파일에서 이미지 등

# %%
from keras.models import load_model  # TensorFlow is required for Keras to work
import cv2  # Install opencv-python
import numpy as np

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Load the model
model = load_model("keras_Model.h5", compile=False)

# Load the labels
class_names = open("labels.txt", "r").readlines()

# CAMERA can be 0 or 1 based on default camera of your computer
camera = cv2.VideoCapture(0)

while True:
    # Grab the webcamera's image.
    ret, image = camera.read()

    # Resize the raw image into (224-height,224-width) pixels
    image = cv2.resize(image, (224, 224), interpolation=cv2.INTER_AREA)

    # Show the image in a window
    cv2.imshow("Webcam Image", image)

    # Make the image a numpy array and reshape it to the models input shape.
    image = np.asarray(image, dtype=np.float32).reshape(1, 224, 224, 3)

    # Normalize the image array
    image = (image / 127.5) - 1

    # Predicts the model
    prediction = model.predict(image)
    index = np.argmax(prediction)
    class_name = class_names[index]
    confidence_score = prediction[0][index]

    # Print prediction and confidence score
    print("Class:", class_name[2:], end="")
    print("Confidence Score:", str(np.round(confidence_score * 100))[:-2], "%")

    # Listen to the keyboard for presses.
    keyboard_input = cv2.waitKey(1)

    # 27 is the ASCII for the esc key on your keyboard.
    if keyboard_input == 27:
        break

camera.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 1s 1s/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 43ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 47ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 45ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 42ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 41ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 43ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 41ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 43ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 45ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 45ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 49ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 43ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 46ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 54ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 44ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 44ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 41ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 43ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 44ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 44ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 44ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 42ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: 개
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 37ms/step
# Class: 개
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 42ms/step
# Class: 개
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 55ms/step
# Class: 개
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 42ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 47ms/step
# Class: 개
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 49ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 44ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 41ms/step
# Class: 개
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 38ms/step
# Class: 개
# Confidence Score: 93 %
# 1/1 [==============================] - 0s 39ms/step
# Class: 개
# Confidence Score: 60 %
# 1/1 [==============================] - 0s 38ms/step
# Class: 고
# Confidence Score: 75 %
# 1/1 [==============================] - 0s 42ms/step
# Class: 고
# Confidence Score: 82 %
# 1/1 [==============================] - 0s 43ms/step
# Class: 고
# Confidence Score: 93 %
# 1/1 [==============================] - 0s 42ms/step
# Class: 고
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 53ms/step
# Class: 고
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 41ms/step
# Class: 고
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 43ms/step
# Class: 고
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: 고
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 41ms/step
# Class: 고
# Confidence Score: 76 %
# 1/1 [==============================] - 0s 43ms/step
# Class: 고
# Confidence Score: 70 %
# 1/1 [==============================] - 0s 44ms/step
# Class: 개
# Confidence Score: 89 %
# 1/1 [==============================] - 0s 41ms/step
# Class: 개
# Confidence Score: 58 %
# 1/1 [==============================] - 0s 47ms/step
# Class: 개
# Confidence Score: 46 %
# 1/1 [==============================] - 0s 45ms/step
# Class: 개
# Confidence Score: 76 %
# 1/1 [==============================] - 0s 40ms/step
# Class: 개
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 37ms/step
# Class: 개
# Confidence Score: 79 %
# 1/1 [==============================] - 0s 37ms/step
# Class: 개
# Confidence Score: 94 %
# 1/1 [==============================] - 0s 44ms/step
# Class: 개
# Confidence Score: 88 %
# 1/1 [==============================] - 0s 40ms/step
# Class: 개
# Confidence Score: 83 %
# 1/1 [==============================] - 0s 49ms/step
# Class: 개
# Confidence Score: 90 %
# 1/1 [==============================] - 0s 45ms/step
# Class: 개
# Confidence Score: 87 %
# 1/1 [==============================] - 0s 41ms/step
# Class: 개
# Confidence Score: 95 %
# 1/1 [==============================] - 0s 36ms/step
# Class: 개
# Confidence Score: 94 %
# 1/1 [==============================] - 0s 43ms/step
# Class: 개
# Confidence Score: 96 %
# 1/1 [==============================] - 0s 41ms/step
# Class: 개
# Confidence Score: 96 %
# 1/1 [==============================] - 0s 38ms/step
# Class: 개
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 45ms/step
# Class: 개
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 42ms/step
# Class: 개
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 38ms/step
# Class: 개
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 41ms/step
# Class: 개
# Confidence Score: 95 %
# 1/1 [==============================] - 0s 41ms/step
# Class: 개
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 43ms/step
# Class: 개
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 38ms/step
# Class: 개
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 40ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 43ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 48ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 44ms/step
# Class: 개
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 42ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 46ms/step
# Class: 개
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 42ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 44ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 43ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 43ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 44ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 41ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 43ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 43ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 42ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 46ms/step
# Class: 개
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 40ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 44ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 47ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 44ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 48ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 50ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 66ms/step
# Class: 개
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 43ms/step
# Class: 개
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 42ms/step
# Class: 개
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 42ms/step
# Class: 개
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 39ms/step
# Class: 개
# Confidence Score: 88 %
# 1/1 [==============================] - 0s 45ms/step
# Class: 개
# Confidence Score: 96 %
# 1/1 [==============================] - 0s 40ms/step
# Class: 개
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 52ms/step
# Class: 개
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 40ms/step
# Class: 개
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 39ms/step
# Class: 개
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 47ms/step
# Class: 개
# Confidence Score: 96 %
# 1/1 [==============================] - 0s 43ms/step
# Class: 개
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 43ms/step
# Class: 개
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 44ms/step
# Class: 개
# Confidence Score: 96 %
# 1/1 [==============================] - 0s 53ms/step
# Class: 개
# Confidence Score: 94 %
# 1/1 [==============================] - 0s 42ms/step
# Class: 개
# Confidence Score: 92 %
# 1/1 [==============================] - 0s 46ms/step
# Class: 개
# Confidence Score: 70 %
# 1/1 [==============================] - 0s 36ms/step
# Class: 개
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 42ms/step
# Class: 개
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 42ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 51ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 44ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 47ms/step
# Class: 개
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 44ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 51ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 43ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 43ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 44ms/step
# Class: 개
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 42ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 45ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 48ms/step
# Class: 개
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: 개
# Confidence Score: 100 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 34
#      31 image = (image / 127.5) - 1
#      33 # Predicts the model
# ---> 34 prediction = model.predict(image)
#      35 index = np.argmax(prediction)
#      36 class_name = class_names[index]
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\keras\src\engine\training.py:2651, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2649     self._steps_per_execution_tuner.start()
#    2650 batch_outputs = None
# -> 2651 for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    2652     with data_handler.catch_stop_iteration():
#    2653         for step in data_handler.steps():
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\keras\src\engine\data_adapter.py:1341, in DataHandler.enumerate_epochs(self)
#    1339 """Yields `(epoch, tf.data.Iterator)`."""
#    1340 with self._truncate_execution_to_epoch():
# -> 1341     data_iterator = iter(self._dataset)
#    1342     for epoch in range(self._initial_epoch, self._epochs):
#    1343         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:500, in DatasetV2.__iter__(self)
#     498 if context.executing_eagerly() or ops.inside_function():
#     499   with ops.colocate_with(self._variant_tensor):
# --> 500     return iterator_ops.OwnedIterator(self)
#     501 else:
#     502   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     503                      "iteration in eager mode or within tf.function.")
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:706, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     702   if (components is not None or element_spec is not None):
#     703     raise ValueError(
#     704         "When `dataset` is provided, `element_spec` and `components` must "
#     705         "not be specified.")
# --> 706   self._create_iterator(dataset)
#     708 self._get_next_call_count = 0
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:745, in OwnedIterator._create_iterator(self, dataset)
#     742   assert len(fulltype.args[0].args[0].args) == len(
#     743       self._flat_output_types)
#     744   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 745 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3421, in make_iterator(dataset, iterator, name)
#    3419 if tld.is_eager:
#    3420   try:
# -> 3421     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3422       _ctx, "MakeIterator", name, dataset, iterator)
#    3423     return _result
#    3424   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
