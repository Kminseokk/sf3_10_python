# %%
import cv2

def detect_faces():
    # 웹캠을 켭니다.
    cap = cv2.VideoCapture(0)

    # 얼굴 인식을 위해 얼굴 검출기를 로드합니다.
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

    while True:
        # 웹캠으로부터 영상을 받아옵니다.
        ret, frame = cap.read()

        if not ret:
            break

        # 영상을 회색으로 변환합니다.
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # 얼굴을 검출합니다.
        # faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
        faces = face_cascade.detectMultiScale(gray)

        # 검출된 얼굴 주위에 사각형을 그립니다.
        for (x, y, w, h) in faces:
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
            cv2.putText(frame, 'Face', (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

        # 결과 영상을 화면에 출력합니다.
        cv2.imshow('Face Detection', frame)

        # 'q'를 누르면 종료합니다.
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # 웹캠을 끕니다.
    cap.release()
    cv2.destroyAllWindows()

# 웹캠으로부터 얼굴을 인식합니다.
detect_faces()

# %%
import datetime
import cv2

capture = cv2.VideoCapture("sample_1280x720_surfing_with_audio.avi")
fourcc = cv2.VideoWriter_fourcc(*'XVID')
record = False

while True:
    if(capture.get(cv2.CAP_PROP_POS_FRAMES) == capture.get(cv2.CAP_PROP_FRAME_COUNT)-1):
        capture.open("./deeplearning/opencv/sample_1280x720_surfing_with_audio.avi")

    ret, frame = capture.read()
    cv2.imshow("VideoFrame", frame)

    now = datetime.datetime.now().strftime("%d_%H-%M-%S")
    key = cv2.waitKey(33)

    if key == 27: #ESC
        break
    elif key == ord('c'):
        print("캡쳐")
        cv2.imwrite("C:/Users/gamec/Downloads/" + str(now) + ".png", frame)
    elif key == ord('r'):
        print("녹화 시작")
        record = True
        video = cv2.VideoWriter("C:/Users/gamec/Downloads/" + str(now) + ".avi", fourcc, 20.0, (frame.shape[1], frame.shape[0]))
    elif key == ord('s'):
        print("녹화 중지")
        record = False
        video.release()
        
    if record == True:
        print("녹화 중..")
        video.write(frame)

capture.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

def mouse_event(event, x, y, flags, param):
    print("event x y flags", event, x, y, flags)
    diff = 2
    global radius
    
    if event == cv2.EVENT_LBUTTONDOWN:
        cv2.circle(param, (x, y), radius, (255, 0, 0), 2)
        cv2.imshow("draw", src)

    elif event == cv2.EVENT_MOUSEWHEEL:
        if flags > 0:
            radius += diff
        elif radius > 1:
            radius -= diff

radius = 5
src = np.full((500, 500, 3), 255, dtype=np.uint8)

cv2.imshow("draw", src)
cv2.setMouseCallback("draw", mouse_event, src)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# event x y flags 0 484 405 0
# event x y flags 0 453 389 0
# event x y flags 0 422 372 0
# event x y flags 0 395 356 0
# event x y flags 0 368 343 0
# event x y flags 0 346 329 0
# event x y flags 0 329 318 0
# event x y flags 0 314 309 0
# event x y flags 0 302 302 0
# event x y flags 0 289 293 0
# event x y flags 0 279 286 0
# event x y flags 0 268 279 0
# event x y flags 0 260 273 0
# event x y flags 0 252 266 0
# event x y flags 0 244 259 0
# event x y flags 0 238 253 0
# event x y flags 0 233 247 0
# event x y flags 0 228 241 0
# event x y flags 0 224 236 0
# event x y flags 0 221 232 0
# event x y flags 0 218 227 0
# event x y flags 0 216 224 0
# event x y flags 0 214 221 0
# event x y flags 0 212 218 0
# event x y flags 0 210 216 0
# event x y flags 0 209 214 0
# event x y flags 0 207 211 0
# event x y flags 0 205 208 0
# event x y flags 0 204 205 0
# event x y flags 0 203 202 0
# event x y flags 0 203 200 0
# event x y flags 0 203 199 0
# event x y flags 0 203 198 0
# event x y flags 1 203 198 1
# event x y flags 4 203 198 0
# event x y flags 0 203 198 0
# event x y flags 0 203 197 0
# event x y flags 0 204 197 0
# event x y flags 0 206 197 0
# event x y flags 0 208 197 0
# event x y flags 0 209 197 0
# event x y flags 0 212 197 0
# event x y flags 0 215 197 0
# event x y flags 0 219 196 0
# event x y flags 0 220 196 0
# event x y flags 0 224 195 0
# event x y flags 0 226 194 0
# event x y flags 0 228 194 0
# event x y flags 0 231 193 0
# event x y flags 0 234 192 0
# event x y flags 0 236 191 0
# event x y flags 0 241 189 0
# event x y flags 0 245 188 0
# event x y flags 0 249 187 0
# event x y flags 0 253 185 0
# event x y flags 0 257 183 0
# event x y flags 0 261 182 0
# event x y flags 0 265 180 0
# event x y flags 0 268 179 0
# event x y flags 0 271 178 0
# event x y flags 0 274 177 0
# event x y flags 0 276 175 0
# event x y flags 0 279 174 0
# event x y flags 0 281 173 0
# event x y flags 0 282 172 0
# event x y flags 0 284 171 0
# event x y flags 0 286 170 0
# event x y flags 0 288 169 0
# event x y flags 0 289 168 0
# event x y flags 0 291 167 0
# event x y flags 0 293 166 0
# event x y flags 0 294 165 0
# event x y flags 1 294 165 1
# event x y flags 0 294 168 1
# event x y flags 0 293 171 1
# event x y flags 0 293 173 1
# event x y flags 0 292 180 1
# event x y flags 0 291 186 1
# event x y flags 0 288 193 1
# event x y flags 0 286 199 1
# event x y flags 0 284 205 1
# event x y flags 0 280 213 1
# event x y flags 0 277 220 1
# event x y flags 0 273 228 1
# event x y flags 0 268 236 1
# event x y flags 0 263 243 1
# event x y flags 0 259 250 1
# event x y flags 0 256 256 1
# event x y flags 0 252 262 1
# event x y flags 0 248 268 1
# event x y flags 0 245 272 1
# event x y flags 0 242 277 1
# event x y flags 0 239 280 1
# event x y flags 0 234 283 1
# event x y flags 0 231 286 1
# event x y flags 0 227 290 1
# event x y flags 0 222 292 1
# event x y flags 0 218 293 1
# event x y flags 0 215 294 1
# event x y flags 0 213 295 1
# event x y flags 0 211 295 1
# event x y flags 0 208 295 1
# event x y flags 0 206 295 1
# event x y flags 0 204 295 1
# event x y flags 0 201 295 1
# event x y flags 0 197 295 1
# event x y flags 0 194 293 1
# event x y flags 0 191 291 1
# event x y flags 0 188 289 1
# event x y flags 0 185 286 1
# event x y flags 0 182 283 1
# event x y flags 0 179 280 1
# event x y flags 0 176 277 1
# event x y flags 0 174 274 1
# event x y flags 0 172 270 1
# event x y flags 0 170 265 1
# event x y flags 0 168 260 1
# event x y flags 0 167 256 1
# event x y flags 0 166 252 1
# event x y flags 0 164 246 1
# event x y flags 0 164 244 1
# event x y flags 0 164 240 1
# event x y flags 0 164 238 1
# event x y flags 0 164 235 1
# event x y flags 0 164 232 1
# event x y flags 0 164 229 1
# event x y flags 0 165 224 1
# event x y flags 0 167 220 1
# event x y flags 0 169 217 1
# event x y flags 0 172 214 1
# event x y flags 0 175 211 1
# event x y flags 0 179 207 1
# event x y flags 0 184 204 1
# event x y flags 0 188 201 1
# event x y flags 0 191 199 1
# event x y flags 0 194 197 1
# event x y flags 0 196 196 1
# event x y flags 4 196 196 0
# event x y flags 0 196 195 0
# event x y flags 0 197 194 0
# event x y flags 0 197 194 0
# event x y flags 1 197 194 1
# event x y flags 0 198 194 1
# event x y flags 0 201 195 1
# event x y flags 0 202 198 1
# event x y flags 0 205 202 1
# event x y flags 0 208 207 1
# event x y flags 0 210 211 1
# event x y flags 0 213 215 1
# event x y flags 0 216 220 1
# event x y flags 0 219 224 1
# event x y flags 0 221 228 1
# event x y flags 0 223 233 1
# event x y flags 0 225 236 1
# event x y flags 0 227 239 1
# event x y flags 0 228 240 1
# event x y flags 0 230 242 1
# event x y flags 0 231 244 1
# event x y flags 0 232 246 1
# event x y flags 0 232 247 1
# event x y flags 4 232 247 0
# event x y flags 0 232 247 0
# event x y flags 1 232 247 1
# event x y flags 4 232 247 0
# event x y flags 0 232 247 0
# event x y flags 7 232 247 1
# event x y flags 0 232 248 1
# event x y flags 0 233 249 1
# event x y flags 0 234 249 1
# event x y flags 0 236 250 1
# event x y flags 0 236 252 1
# event x y flags 0 237 254 1
# event x y flags 0 238 255 1
# event x y flags 0 239 257 1
# event x y flags 0 240 259 1
# event x y flags 0 240 261 1
# event x y flags 0 241 263 1
# event x y flags 0 241 265 1
# event x y flags 0 242 269 1
# event x y flags 0 243 273 1
# event x y flags 0 244 277 1
# event x y flags 0 245 281 1
# event x y flags 0 245 284 1
# event x y flags 0 246 288 1
# event x y flags 0 246 290 1
# event x y flags 0 247 293 1
# event x y flags 0 248 296 1
# event x y flags 0 249 298 1
# event x y flags 0 249 300 1
# event x y flags 0 250 302 1
# event x y flags 0 251 305 1
# event x y flags 0 252 306 1
# event x y flags 0 253 309 1
# event x y flags 0 254 311 1
# event x y flags 0 255 313 1
# event x y flags 0 255 314 1
# event x y flags 4 255 314 0
# event x y flags 1 255 314 1
# event x y flags 4 255 314 0
# event x y flags 0 255 314 0
# event x y flags 7 255 314 1
# event x y flags 4 255 314 0
# event x y flags 1 255 314 1
# event x y flags 4 255 314 0
# event x y flags 0 255 314 0
# event x y flags 7 255 314 1
# event x y flags 0 256 315 1
# event x y flags 4 256 315 0
# event x y flags 0 257 312 0
# event x y flags 0 259 308 0
# event x y flags 0 261 304 0
# event x y flags 0 263 300 0
# event x y flags 0 266 295 0
# event x y flags 0 270 291 0
# event x y flags 0 273 286 0
# event x y flags 0 278 281 0
# event x y flags 0 284 276 0
# event x y flags 0 290 271 0
# event x y flags 0 295 267 0
# event x y flags 0 301 262 0
# event x y flags 0 304 260 0
# event x y flags 0 308 258 0
# event x y flags 0 310 256 0
# event x y flags 0 312 255 0
# event x y flags 0 313 254 0
# event x y flags 1 313 254 1
# event x y flags 4 313 254 0
# event x y flags 0 313 254 0
# event x y flags 0 314 255 0
# event x y flags 0 314 258 0
# event x y flags 0 314 260 0
# event x y flags 0 316 266 0
# event x y flags 0 317 271 0
# event x y flags 0 318 277 0
# event x y flags 0 319 283 0
# event x y flags 0 319 287 0
# event x y flags 0 319 292 0
# event x y flags 0 319 297 0
# event x y flags 0 319 302 0
# event x y flags 0 319 306 0
# event x y flags 0 319 309 0
# event x y flags 0 319 311 0
# event x y flags 0 319 312 0
# event x y flags 0 319 313 0
# event x y flags 0 319 314 0
# event x y flags 1 319 314 1
# event x y flags 0 320 315 1
# event x y flags 4 320 315 0
# event x y flags 0 320 315 0
# event x y flags 0 320 314 0
# event x y flags 0 321 311 0
# event x y flags 0 322 308 0
# event x y flags 0 323 304 0
# event x y flags 0 326 300 0
# event x y flags 0 328 294 0
# event x y flags 0 332 288 0
# event x y flags 0 335 280 0
# event x y flags 0 340 274 0
# event x y flags 0 345 268 0
# event x y flags 0 350 262 0
# event x y flags 0 355 255 0
# event x y flags 0 360 249 0
# event x y flags 0 365 245 0
# event x y flags 0 370 238 0
# event x y flags 0 375 235 0
# event x y flags 0 378 230 0
# event x y flags 0 380 227 0
# event x y flags 0 382 225 0
# event x y flags 0 383 222 0
# event x y flags 0 384 220 0
# event x y flags 0 384 219 0
# event x y flags 0 384 218 0
# event x y flags 1 384 218 1
# event x y flags 4 384 218 0
# event x y flags 0 384 218 0
# event x y flags 0 384 215 0
# event x y flags 0 384 214 0
# event x y flags 0 386 208 0
# event x y flags 0 387 203 0
# event x y flags 0 388 197 0
# event x y flags 0 389 190 0
# event x y flags 0 390 182 0
# event x y flags 0 393 175 0
# event x y flags 0 397 167 0
# event x y flags 0 400 159 0
# event x y flags 0 404 150 0
# event x y flags 0 410 141 0
# event x y flags 0 414 131 0
# event x y flags 0 418 124 0
# event x y flags 0 420 116 0
# event x y flags 0 424 109 0
# event x y flags 0 428 103 0
# event x y flags 0 431 96 0
# event x y flags 0 434 89 0
# event x y flags 0 435 83 0
# event x y flags 0 438 77 0
# event x y flags 0 441 73 0
# event x y flags 0 444 67 0
# event x y flags 0 446 64 0
# event x y flags 0 448 60 0
# event x y flags 0 450 57 0
# event x y flags 0 452 54 0
# event x y flags 0 454 51 0
# event x y flags 0 455 49 0
# event x y flags 0 457 46 0
# event x y flags 0 458 45 0
# event x y flags 0 459 42 0
# event x y flags 0 460 40 0
# event x y flags 0 461 39 0
# event x y flags 0 463 37 0
# event x y flags 0 464 35 0
# event x y flags 0 465 34 0
# event x y flags 0 467 32 0
# event x y flags 0 469 30 0
# event x y flags 0 470 29 0
# event x y flags 0 471 28 0
# event x y flags 0 472 27 0
# event x y flags 0 472 26 0
# event x y flags 0 473 24 0
# event x y flags 0 474 22 0
# event x y flags 0 474 21 0
# event x y flags 0 474 20 0
# event x y flags 0 474 19 0
# event x y flags 0 475 17 0
# event x y flags 0 476 16 0
# event x y flags 0 477 16 0
# event x y flags 0 477 15 0
# event x y flags 0 477 14 0
# event x y flags 0 477 13 0
# event x y flags 0 477 12 0
# event x y flags 0 477 10 0
# event x y flags 0 477 9 0
# event x y flags 0 477 8 0
# event x y flags 0 477 7 0
# event x y flags 0 477 5 0
# event x y flags 0 477 4 0
# event x y flags 0 477 3 0
# event x y flags 0 477 2 0
# event x y flags 0 477 1 0
# event x y flags 0 477 0 0

# %%
#실습 5
import cv2

history = []
radius = 5

def mouse_event(event, x, y, flags, param):
    print("event x y flags", event, x, y, flags)
    diff = 2
    global radius

    if event == cv2.EVENT_RBUTTONDOWN:
        history.append((x, y))

    elif event == cv2.EVENT_MOUSEWHEEL:
        if flags > 0:
            radius += diff
        elif radius > 1:
            radius -= diff


capture = cv2.VideoCapture(0)
# capture.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
# capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)

cv2.namedWindow("VideoFrame")
cv2.setMouseCallback("VideoFrame", mouse_event)

while cv2.waitKey(10) < 0:
    ret, frame = capture.read()
    for x, y in history:
        cv2.circle(frame, (x, y), radius, (255, 0, 0), 2)

    cv2.imshow("VideoFrame", frame)

capture.release()
cv2.destroyAllWindows()
# Out:
# event x y flags 0 517 367 0
# event x y flags 0 517 367 0
# event x y flags 0 517 367 0
# event x y flags 0 517 368 0
# event x y flags 0 512 368 0
# event x y flags 0 508 367 0
# event x y flags 0 488 370 0
# event x y flags 0 479 371 0
# event x y flags 0 459 375 0
# event x y flags 0 458 375 0
# event x y flags 0 456 375 0
# event x y flags 0 455 375 0
# event x y flags 0 452 374 0
# event x y flags 0 448 368 0
# event x y flags 0 443 365 0
# event x y flags 0 432 354 0
# event x y flags 0 425 346 0
# event x y flags 0 417 336 0
# event x y flags 0 394 311 0
# event x y flags 0 358 284 0
# event x y flags 0 330 263 0
# event x y flags 0 309 248 0
# event x y flags 0 296 239 0
# event x y flags 0 291 235 0
# event x y flags 0 290 235 0
# event x y flags 1 290 235 1
# event x y flags 4 290 235 0
# event x y flags 0 290 235 0
# event x y flags 0 293 235 0
# event x y flags 0 295 236 0
# event x y flags 0 297 236 0
# event x y flags 0 298 237 0
# event x y flags 0 305 238 0
# event x y flags 0 310 237 0
# event x y flags 0 316 234 0
# event x y flags 0 318 232 0
# event x y flags 0 320 230 0
# event x y flags 0 322 225 0
# event x y flags 0 324 222 0
# event x y flags 0 329 212 0
# event x y flags 0 333 203 0
# event x y flags 0 335 196 0
# event x y flags 0 342 179 0
# event x y flags 0 349 162 0
# event x y flags 0 354 149 0
# event x y flags 0 361 138 0
# event x y flags 0 361 137 0
# event x y flags 2 361 137 2
# event x y flags 5 361 137 0
# event x y flags 0 361 137 0
# event x y flags 0 360 139 0
# event x y flags 0 359 141 0
# event x y flags 0 358 145 0
# event x y flags 0 356 150 0
# event x y flags 0 355 155 0
# event x y flags 0 354 159 0
# event x y flags 0 351 162 0
# event x y flags 0 348 165 0
# event x y flags 0 347 167 0
# event x y flags 0 346 170 0
# event x y flags 0 344 175 0
# event x y flags 0 342 183 0
# event x y flags 0 341 186 0
# event x y flags 0 340 189 0
# event x y flags 0 340 190 0
# event x y flags 0 339 192 0
# event x y flags 0 338 195 0
# event x y flags 0 338 198 0
# event x y flags 0 337 201 0
# event x y flags 0 337 211 0
# event x y flags 0 337 213 0
# event x y flags 1 337 213 1
# event x y flags 0 337 215 1
# event x y flags 0 337 217 1
# event x y flags 0 336 220 1
# event x y flags 0 335 228 1
# event x y flags 0 335 235 1
# event x y flags 0 335 244 1
# event x y flags 0 335 249 1
# event x y flags 0 335 265 1
# event x y flags 0 335 271 1
# event x y flags 0 335 280 1
# event x y flags 0 335 282 1
# event x y flags 0 335 283 1
# event x y flags 0 335 284 1
# event x y flags 4 335 284 0
# event x y flags 0 335 284 0
# event x y flags 0 333 285 0
# event x y flags 0 332 283 0
# event x y flags 0 330 280 0
# event x y flags 0 324 270 0
# event x y flags 0 319 262 0
# event x y flags 0 314 254 0
# event x y flags 0 306 236 0
# event x y flags 0 302 225 0
# event x y flags 0 298 208 0
# event x y flags 0 297 196 0
# event x y flags 0 299 179 0
# event x y flags 0 310 165 0
# event x y flags 0 316 159 0
# event x y flags 1 316 159 1
# event x y flags 0 322 155 1
# event x y flags 0 338 147 1
# event x y flags 0 340 146 1
# event x y flags 0 341 146 1
# event x y flags 0 342 146 1
# event x y flags 0 343 148 1
# event x y flags 4 343 148 0
# event x y flags 0 346 159 0
# event x y flags 0 347 163 0
# event x y flags 0 348 172 0
# event x y flags 0 349 176 0
# event x y flags 0 351 184 0
# event x y flags 0 352 188 0
# event x y flags 0 352 193 0
# event x y flags 1 352 193 1
# event x y flags 0 353 195 1
# event x y flags 0 353 197 1
# event x y flags 0 353 204 1
# event x y flags 0 353 208 1
# event x y flags 0 353 212 1
# event x y flags 0 354 224 1
# event x y flags 0 356 231 1
# event x y flags 0 356 234 1
# event x y flags 0 356 238 1
# event x y flags 0 356 241 1
# event x y flags 0 356 242 1
# event x y flags 0 356 244 1
# event x y flags 0 356 245 1
# event x y flags 4 356 245 0
# event x y flags 0 356 245 0
# event x y flags 0 356 246 0
# event x y flags 0 356 247 0
# event x y flags 0 356 248 0
# event x y flags 1 356 248 1
# event x y flags 4 356 248 0
# event x y flags 0 356 248 0
# event x y flags 0 354 248 0
# event x y flags 0 351 248 0
# event x y flags 0 349 248 0
# event x y flags 0 348 248 0
# event x y flags 0 327 241 0
# event x y flags 0 315 239 0
# event x y flags 0 310 238 0
# event x y flags 0 304 236 0
# event x y flags 0 294 234 0
# event x y flags 0 289 234 0
# event x y flags 0 286 234 0
# event x y flags 1 286 234 1
# event x y flags 4 286 234 0
# event x y flags 0 286 234 0
# event x y flags 7 286 234 1
# event x y flags 4 286 234 0
# event x y flags 2 286 234 2
# event x y flags 5 286 234 0
# event x y flags 0 286 234 0
# event x y flags 0 286 233 0
# event x y flags 0 287 229 0
# event x y flags 0 289 227 0
# event x y flags 0 292 225 0
# event x y flags 0 295 222 0
# event x y flags 0 299 219 0
# event x y flags 0 305 214 0
# event x y flags 0 311 210 0
# event x y flags 0 316 206 0
# event x y flags 0 320 203 0
# event x y flags 0 323 199 0
# event x y flags 0 325 198 0
# event x y flags 0 328 196 0
# event x y flags 2 328 196 2
# event x y flags 5 328 196 0
# event x y flags 0 328 196 0
# event x y flags 0 330 196 0
# event x y flags 0 334 196 0
# event x y flags 0 341 198 0
# event x y flags 0 353 202 0
# event x y flags 0 368 207 0
# event x y flags 0 382 210 0
# event x y flags 0 394 213 0
# event x y flags 0 399 215 0
# event x y flags 0 400 216 0
# event x y flags 0 403 220 0
# event x y flags 0 404 222 0
# event x y flags 0 404 223 0
# event x y flags 0 404 224 0
# event x y flags 0 405 225 0
# event x y flags 2 405 225 2
# event x y flags 5 405 225 0
# event x y flags 0 405 225 0
# event x y flags 0 399 222 0
# event x y flags 0 387 217 0
# event x y flags 0 367 208 0
# event x y flags 0 343 200 0
# event x y flags 0 323 191 0
# event x y flags 0 306 185 0
# event x y flags 0 299 183 0
# event x y flags 0 298 182 0
# event x y flags 0 297 182 0
# event x y flags 2 297 182 2
# event x y flags 5 297 182 0
# event x y flags 0 297 182 0
# event x y flags 0 298 182 0
# event x y flags 0 303 182 0
# event x y flags 0 306 182 0
# event x y flags 0 310 182 0
# event x y flags 0 324 182 0
# event x y flags 0 334 182 0
# event x y flags 0 364 182 0
# event x y flags 0 373 182 0
# event x y flags 0 389 184 0
# event x y flags 2 389 184 2
# event x y flags 0 390 186 2
# event x y flags 5 390 186 0
# event x y flags 0 390 187 0
# event x y flags 0 390 190 0
# event x y flags 0 390 199 0
# event x y flags 0 390 201 0
# event x y flags 0 390 210 0
# event x y flags 0 389 212 0
# event x y flags 0 388 215 0
# event x y flags 0 388 216 0
# event x y flags 2 388 216 2
# event x y flags 0 387 217 2
# event x y flags 0 386 219 2
# event x y flags 0 385 220 2
# event x y flags 0 384 222 2
# event x y flags 0 384 223 2
# event x y flags 5 384 223 0
# event x y flags 0 382 224 0
# event x y flags 0 380 227 0
# event x y flags 0 377 230 0
# event x y flags 0 371 239 0
# event x y flags 0 369 243 0
# event x y flags 0 364 252 0
# event x y flags 0 358 258 0
# event x y flags 0 354 262 0
# event x y flags 0 353 263 0
# event x y flags 2 353 263 2
# event x y flags 5 353 263 0
# event x y flags 0 351 260 0
# event x y flags 0 350 250 0
# event x y flags 0 350 240 0
# event x y flags 0 350 229 0
# event x y flags 0 349 221 0
# event x y flags 0 349 217 0
# event x y flags 0 349 214 0
# event x y flags 0 349 209 0
# event x y flags 0 349 208 0
# event x y flags 0 349 207 0
# event x y flags 2 349 207 2
# event x y flags 0 349 206 2
# event x y flags 5 349 206 0
# event x y flags 0 349 206 0
# event x y flags 0 348 206 0
# event x y flags 0 347 205 0
# event x y flags 0 343 204 0
# event x y flags 0 340 204 0
# event x y flags 0 332 202 0
# event x y flags 0 327 201 0
# event x y flags 0 323 200 0
# event x y flags 0 319 199 0
# event x y flags 0 317 199 0
# event x y flags 0 315 199 0
# event x y flags 2 315 199 2
# event x y flags 5 315 199 0
# event x y flags 0 315 197 0
# event x y flags 0 317 197 0
# event x y flags 0 320 196 0
# event x y flags 0 322 196 0
# event x y flags 0 324 196 0
# event x y flags 0 325 196 0
# event x y flags 2 325 196 2
# event x y flags 0 326 196 2
# event x y flags 5 326 196 0
# event x y flags 0 327 196 0
# event x y flags 0 329 197 0
# event x y flags 0 331 198 0
# event x y flags 0 332 199 0
# event x y flags 2 332 199 2
# event x y flags 0 333 200 2
# event x y flags 0 336 201 2
# event x y flags 0 338 202 2
# event x y flags 0 340 202 2
# event x y flags 0 341 202 2
# event x y flags 0 342 202 2
# event x y flags 0 343 202 2
# event x y flags 5 343 202 0
# event x y flags 0 343 202 0
# event x y flags 2 343 202 2
# event x y flags 0 349 202 2
# event x y flags 0 363 204 2
# event x y flags 0 378 207 2
# event x y flags 5 378 207 0
# event x y flags 0 394 211 0
# event x y flags 0 400 212 0
# event x y flags 0 406 213 0
# event x y flags 0 407 213 0
# event x y flags 2 407 213 2
# event x y flags 0 409 214 2
# event x y flags 0 411 215 2
# event x y flags 5 411 215 0
# event x y flags 0 413 216 0
# event x y flags 0 413 216 0
# event x y flags 0 414 216 0
# event x y flags 0 416 217 0
# event x y flags 2 416 217 2
# event x y flags 5 416 217 0
# event x y flags 0 416 217 0
# event x y flags 0 416 216 0
# event x y flags 0 413 215 0
# event x y flags 0 396 212 0
# event x y flags 0 385 210 0
# event x y flags 0 378 208 0
# event x y flags 0 376 207 0
# event x y flags 0 375 207 0
# event x y flags 2 375 207 2
# event x y flags 5 375 207 0
# event x y flags 0 374 207 0
# event x y flags 0 373 207 0
# event x y flags 0 372 207 0
# event x y flags 2 372 207 2
# event x y flags 0 370 206 2
# event x y flags 0 369 206 2
# event x y flags 0 366 206 2
# event x y flags 0 364 206 2
# event x y flags 0 363 206 2
# event x y flags 0 357 205 2
# event x y flags 0 355 205 2
# event x y flags 0 351 204 2
# event x y flags 0 346 203 2
# event x y flags 0 343 202 2
# event x y flags 0 335 201 2
# event x y flags 0 325 201 2
# event x y flags 0 321 201 2
# event x y flags 5 321 201 0
# event x y flags 0 321 201 0
# event x y flags 0 320 201 0
# event x y flags 0 319 201 0
# event x y flags 2 319 201 2
# event x y flags 0 318 201 2
# event x y flags 0 312 200 2
# event x y flags 0 310 200 2
# event x y flags 0 304 199 2
# event x y flags 5 304 199 0
# event x y flags 0 300 199 0
# event x y flags 0 297 199 0
# event x y flags 0 286 199 0
# event x y flags 0 282 199 0
# event x y flags 0 277 199 0
# event x y flags 0 274 199 0
# event x y flags 0 272 199 0
# event x y flags 0 269 198 0
# event x y flags 2 269 198 2
# event x y flags 5 269 198 0
# event x y flags 0 269 198 0
# event x y flags 0 268 198 0
# event x y flags 0 267 198 0
# event x y flags 0 265 197 0
# event x y flags 0 262 197 0
# event x y flags 2 262 197 2
# event x y flags 0 260 196 2
# event x y flags 0 260 195 2
# event x y flags 0 259 194 2
# event x y flags 5 259 194 0
# event x y flags 0 257 190 0
# event x y flags 0 257 188 0
# event x y flags 0 256 185 0
# event x y flags 0 255 183 0
# event x y flags 2 255 183 2
# event x y flags 5 255 183 0
# event x y flags 0 255 183 0
# event x y flags 0 255 182 0
# event x y flags 0 256 182 0
# event x y flags 0 257 182 0
# event x y flags 2 257 182 2
# event x y flags 0 258 182 2
# event x y flags 0 261 182 2
# event x y flags 0 266 182 2
# event x y flags 0 278 184 2
# event x y flags 0 287 185 2
# event x y flags 0 303 189 2
# event x y flags 0 312 190 2
# event x y flags 5 312 190 0
# event x y flags 0 319 192 0
# event x y flags 0 329 193 0
# event x y flags 0 332 193 0
# event x y flags 0 333 193 0
# event x y flags 2 333 193 2
# event x y flags 0 339 193 2
# event x y flags 0 347 193 2
# event x y flags 0 360 193 2
# event x y flags 5 360 193 0
# event x y flags 0 374 193 0
# event x y flags 0 389 193 0
# event x y flags 0 402 193 0
# event x y flags 0 411 193 0
# event x y flags 0 418 193 0
# event x y flags 0 423 193 0
# event x y flags 0 426 193 0
# event x y flags 2 426 193 2
# event x y flags 0 428 193 2
# event x y flags 0 432 193 2
# event x y flags 0 435 193 2
# event x y flags 0 443 194 2
# event x y flags 0 445 194 2
# event x y flags 0 448 195 2
# event x y flags 0 449 195 2
# event x y flags 0 448 196 2
# event x y flags 0 441 199 2
# event x y flags 0 437 200 2
# event x y flags 0 430 201 2
# event x y flags 0 407 204 2
# event x y flags 0 364 204 2
# event x y flags 0 347 204 2
# event x y flags 0 331 204 2
# event x y flags 0 316 204 2
# event x y flags 0 302 204 2
# event x y flags 0 283 204 2
# event x y flags 0 277 204 2
# event x y flags 0 276 204 2
# event x y flags 0 277 204 2
# event x y flags 0 286 203 2
# event x y flags 0 311 203 2
# event x y flags 0 347 203 2
# event x y flags 0 393 203 2
# event x y flags 0 445 207 2
# event x y flags 0 475 212 2
# event x y flags 0 485 215 2
# event x y flags 0 486 216 2
# event x y flags 0 477 221 2
# event x y flags 0 441 225 2
# event x y flags 0 412 227 2
# event x y flags 0 302 227 2
# event x y flags 0 259 226 2
# event x y flags 0 171 213 2
# event x y flags 0 159 210 2
# event x y flags 0 152 209 2
# event x y flags 0 153 206 2
# event x y flags 0 161 203 2
# event x y flags 0 209 201 2
# event x y flags 0 233 201 2
# event x y flags 0 290 201 2
# event x y flags 0 318 201 2
# event x y flags 0 371 202 2
# event x y flags 0 378 204 2
# event x y flags 0 381 205 2
# event x y flags 0 382 205 2
# event x y flags 0 378 209 2
# event x y flags 0 358 214 2
# event x y flags 0 328 215 2
# event x y flags 0 297 215 2
# event x y flags 0 273 215 2
# event x y flags 0 267 215 2
# event x y flags 0 264 214 2
# event x y flags 0 267 211 2
# event x y flags 0 282 207 2
# event x y flags 0 308 205 2
# event x y flags 0 325 205 2
# event x y flags 5 325 205 0
# event x y flags 0 342 205 0
# event x y flags 0 377 209 0
# event x y flags 0 402 215 0
# event x y flags 0 408 221 0
# event x y flags 0 409 226 0
# event x y flags 0 403 231 0
# event x y flags 2 403 231 2
# event x y flags 0 355 239 2
# event x y flags 0 322 236 2
# event x y flags 0 289 230 2
# event x y flags 0 262 223 2
# event x y flags 0 252 219 2
# event x y flags 0 250 217 2
# event x y flags 0 252 210 2
# event x y flags 0 258 207 2
# event x y flags 0 300 202 2
# event x y flags 0 315 202 2
# event x y flags 5 315 202 0
# event x y flags 0 354 205 0
# event x y flags 0 358 206 0
# event x y flags 0 361 209 0
# event x y flags 0 361 210 0
# event x y flags 0 361 212 0
# event x y flags 0 353 215 0
# event x y flags 2 353 215 2
# event x y flags 0 350 215 2
# event x y flags 0 337 215 2
# event x y flags 0 328 215 2
# event x y flags 0 317 215 2
# event x y flags 0 293 213 2
# event x y flags 0 281 212 2
# event x y flags 0 268 209 2
# event x y flags 0 243 204 2
# event x y flags 0 234 201 2
# event x y flags 0 228 199 2
# event x y flags 5 228 199 0
# event x y flags 0 225 198 0
# event x y flags 0 224 198 0
# event x y flags 0 223 197 0
# event x y flags 0 231 194 0
# event x y flags 0 247 193 0
# event x y flags 2 247 193 2
# event x y flags 0 259 193 2
# event x y flags 0 273 193 2
# event x y flags 0 305 194 2
# event x y flags 0 337 198 2
# event x y flags 0 362 202 2
# event x y flags 5 362 202 0
# event x y flags 0 369 204 0
# event x y flags 0 370 206 0
# event x y flags 0 370 207 0
# event x y flags 0 366 209 0
# event x y flags 0 365 210 0
# event x y flags 2 365 210 2
# event x y flags 0 363 211 2
# event x y flags 0 361 211 2
# event x y flags 0 360 211 2
# event x y flags 5 360 211 0
# event x y flags 0 360 211 0
# event x y flags 0 364 211 0
# event x y flags 0 367 210 0
# event x y flags 2 367 210 2
# event x y flags 0 368 210 2
# event x y flags 0 373 210 2
# event x y flags 0 375 211 2
# event x y flags 0 378 213 2
# event x y flags 0 379 215 2
# event x y flags 0 379 218 2
# event x y flags 0 374 220 2
# event x y flags 5 374 220 0
# event x y flags 0 369 222 0
# event x y flags 0 360 224 0
# event x y flags 0 337 225 0
# event x y flags 0 322 225 0
# event x y flags 0 309 223 0
# event x y flags 0 283 218 0
# event x y flags 0 274 216 0
# event x y flags 0 268 215 0
# event x y flags 0 265 215 0
# event x y flags 2 265 215 2
# event x y flags 0 263 214 2
# event x y flags 0 262 214 2
# event x y flags 5 262 214 0
# event x y flags 0 262 214 0
# event x y flags 0 262 213 0
# event x y flags 2 262 213 2
# event x y flags 0 264 209 2
# event x y flags 0 266 208 2
# event x y flags 0 269 207 2
# event x y flags 5 269 207 0
# event x y flags 0 277 204 0
# event x y flags 0 282 203 0
# event x y flags 0 304 202 0
# event x y flags 0 311 202 0
# event x y flags 0 330 202 0
# event x y flags 0 334 202 0
# event x y flags 0 337 202 0
# event x y flags 2 337 202 2
# event x y flags 0 338 202 2
# event x y flags 0 339 202 2
# event x y flags 0 343 202 2
# event x y flags 0 345 202 2
# event x y flags 0 347 202 2
# event x y flags 5 347 202 0
# event x y flags 0 349 202 0
# event x y flags 0 352 202 0
# event x y flags 0 355 202 0
# event x y flags 0 355 202 0
# event x y flags 0 358 202 0
# event x y flags 0 360 202 0
# event x y flags 0 361 202 0
# event x y flags 0 362 202 0
# event x y flags 2 362 202 2
# event x y flags 0 363 202 2
# event x y flags 0 364 202 2
# event x y flags 0 369 202 2
# event x y flags 0 374 202 2
# event x y flags 5 374 202 0
# event x y flags 0 382 202 0
# event x y flags 0 391 202 0
# event x y flags 0 397 202 0
# event x y flags 0 399 202 0
# event x y flags 0 400 202 0
# event x y flags 2 400 202 2
# event x y flags 0 402 202 2
# event x y flags 0 403 202 2
# event x y flags 5 403 202 0
# event x y flags 0 403 202 0
# event x y flags 2 403 202 2
# event x y flags 0 401 202 2
# event x y flags 0 399 202 2
# event x y flags 5 399 202 0
# event x y flags 0 398 202 0
# event x y flags 0 396 203 0
# event x y flags 0 395 203 0
# event x y flags 0 394 203 0
# event x y flags 0 387 203 0
# event x y flags 0 382 203 0
# event x y flags 0 371 203 0
# event x y flags 0 359 203 0
# event x y flags 0 343 203 0
# event x y flags 0 337 203 0
# event x y flags 2 337 203 2
# event x y flags 0 332 203 2
# event x y flags 0 325 201 2
# event x y flags 0 321 200 2
# event x y flags 0 312 199 2
# event x y flags 0 306 197 2
# event x y flags 0 302 197 2
# event x y flags 0 300 197 2
# event x y flags 0 297 197 2
# event x y flags 5 297 197 0
# event x y flags 0 297 197 0
# event x y flags 2 297 197 2
# event x y flags 5 297 197 0
# event x y flags 0 296 195 0
# event x y flags 0 297 193 0
# event x y flags 0 300 186 0
# event x y flags 0 303 184 0
# event x y flags 0 312 178 0
# event x y flags 0 318 174 0
# event x y flags 0 324 170 0
# event x y flags 0 350 161 0
# event x y flags 0 361 156 0
# event x y flags 0 402 140 0
# event x y flags 0 417 136 0
# event x y flags 0 445 130 0
# event x y flags 0 457 127 0
# event x y flags 0 468 125 0
# event x y flags 0 490 118 0
# event x y flags 0 497 115 0
# event x y flags 0 503 113 0
# event x y flags 0 509 109 0
# event x y flags 0 515 107 0
# event x y flags 0 521 103 0
# event x y flags 0 530 98 0
# event x y flags 0 539 94 0
# event x y flags 0 544 90 0
# event x y flags 0 548 86 0
# event x y flags 0 551 82 0
# event x y flags 0 552 81 0

# %%
import cv2

def onChange(pos):
    pass

src = cv2.imread("IU.jpg", cv2.IMREAD_GRAYSCALE)

cv2.namedWindow("Trackbar Windows")

cv2.createTrackbar("threshold", "Trackbar Windows", 0, 255, onChange)
cv2.createTrackbar("maxValue", "Trackbar Windows", 0, 255, lambda x : x)

cv2.setTrackbarPos("threshold", "Trackbar Windows", 127)
cv2.setTrackbarPos("maxValue", "Trackbar Windows", 255)

while cv2.waitKey(1) != ord('q'):

    thresh = cv2.getTrackbarPos("threshold", "Trackbar Windows")
    maxval = cv2.getTrackbarPos("maxValue", "Trackbar Windows")

    _, binary = cv2.threshold(src, thresh, maxval, cv2.THRESH_BINARY)

    cv2.imshow("Trackbar Windows", binary)

cv2.destroyAllWindows()

# %%
import cv2

src = cv2.imread("contours.webp", cv2.IMREAD_COLOR)

gray = cv2.cvtColor(src, cv2.COLOR_RGB2GRAY)
ret, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
binary = cv2.bitwise_not(binary)

contours, hierarchy = cv2.findContours(binary, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_NONE)

for i in range(len(contours)):
    cv2.drawContours(src, [contours[i]], 0, (0, 0, 255), 2)
    cv2.putText(src, str(i), tuple(contours[i][0][0]), cv2.FONT_HERSHEY_COMPLEX, 0.8, (0, 255, 0), 1)
    # print(i, hierarchy[0][i])
    cv2.imshow("src", src)
    cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
import cv2

src = cv2.imread("IU.jpg")
dst = src.copy()

gray = cv2.cvtColor(src, cv2.COLOR_RGB2GRAY)
corners = cv2.goodFeaturesToTrack(gray, 100, 0.01, 5, blockSize=3, useHarrisDetector=True, k=0.03)

for i in corners:
    cv2.circle(dst, tuple(map(int, i[0])), 3, (0, 0, 255), 2)

cv2.imshow("dst", dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

src = cv2.imread("IU.jpg")
gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)
result = np.zeros((src.shape[0], 256), dtype=np.uint8)

hist = cv2.calcHist([gray], [0], None, [256], [0, 256])
cv2.normalize(hist, hist, 0, result.shape[0], cv2.NORM_MINMAX)

for x, y in enumerate(hist):
    cv2.line(result, (int(x), result.shape[0]), (int(x), result.shape[0] - int(y)), 255)

dst = np.hstack([gray, result])

cv2.imshow("dst", dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt

# 이미지 로드
img = cv2.imread('IU.jpg')

# OpenCV에서는 색상 채널 순서가 BGR이므로 RGB로 변환
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# 각 채널별로 히스토그램 계산
color = ('r', 'g', 'b')
for i, col in enumerate(color):
    histr = cv2.calcHist([img], [i], None, [256], [0,256])
    plt.plot(histr, color = col)
    plt.xlim([0,256])

plt.title('Histogram for color scale picture')
plt.show()

# %%
import cv2

src = cv2.imread("hats.webp", cv2.IMREAD_GRAYSCALE)
templit = cv2.imread("hat.webp", cv2.IMREAD_GRAYSCALE)
dst = cv2.imread("hats.webp")

result = cv2.matchTemplate(src, templit, cv2.TM_SQDIFF_NORMED)

minVal, maxVal, minLoc, maxLoc = cv2.minMaxLoc(result)
x, y = minLoc
h, w = templit.shape
print(result)
print(x, y)

dst = cv2.rectangle(dst, (x, y), (x +  w, y + h) , (0, 0, 255), 1)
cv2.imshow("dst", dst)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [[0.35533297 0.35373935 0.35233006 ... 0.38107723 0.38054636 0.38003504]
#  [0.35876653 0.3570789  0.35559902 ... 0.37908155 0.37852526 0.37799665]
#  [0.36310115 0.36135522 0.35979638 ... 0.37734947 0.37675878 0.3761936 ]
#  ...
#  [0.33359423 0.33221167 0.33134934 ... 0.5346984  0.52616715 0.51813215]
#  [0.3475707  0.34613252 0.34522045 ... 0.5370005  0.528527   0.5205167 ]
#  [0.36116964 0.3596826  0.35871062 ... 0.53968567 0.5312418  0.52326816]]
# 0 301
